# %% [markdown]
# ### **1. Dataset loading**

# %%
import csv
import pandas as pd

# %%
file_path_train = "../data/train_submission.csv"
file_path_test = "../data/test_without_labels.csv"

data_train = pd.read_csv(file_path_train)

# %% [markdown]
# ### **2. Train dataset analysis**

# %% [markdown]
# **2.1 Non-labeled data suppression**

# %%
data_train_without_nan_for_label = data_train.dropna() # suppression des données non labellisées

# %% [markdown]
# **2.2 Train dataset preprocessing**

# %%
import unicodedata
from collections import defaultdict
import string
import re 
import unicodedata
from tqdm import tqdm
import numpy as np

# %%
def cleaning(text): 
    """
    Fonction pour pré-traiter le texte en enlevant tous les éléments de ponctuation, les chiffres, les double espaces, les URL etc. 
    """

    if not isinstance(text, str):
        return ""

    text = re.sub(r"https?://[^\s]+|www\.[^\s]+", " ", text) # Delete URLs
    text = re.sub(r"\d+", " ", text)  # Delete isolated numbers
    text = text.translate(str.maketrans("", "", string.punctuation))  
    text = ''.join(c for c in text if not (unicodedata.category(c).startswith('P') or unicodedata.category(c) in ['No']))
    text = re.sub(r'[\-\u2010-\u2015]', '', text) # Delete all types of dashes
    text = re.sub(r"['\"‘’‚‛“”„‟‹›«»⹂⹃⸂⸃⸄⸅⸉⸊「」『』〝〞＂ˮ`´ʹʺʻʼʽʾʿˈˊˋ]", '', text)
    text = re.sub(r"\s+", " ", text).strip() # Delete double spaces

    text_cleaned = text.lower() 

    return(text_cleaned)

# %% [markdown]
# Multi-alphabet management for every given label

# %%
SCRIPT_MAP = {
    "LATIN": "Latin",
    "CYRILLIC": "Cyrillique",
    "ARABIC": "Arabe",
    "HEBREW": "Hébreu",
    "GREEK": "Grec",
    "DEVANAGARI": "Devanagari (Hindi, Sanskrit)",
    "HIRAGANA": "Hiragana (Japonais)",
    "KATAKANA": "Katakana (Japonais)",
    "CJK": "Kanji (Chinois, Japonais, Coréen)",
    "HANGUL": "Hangul (Coréen)",
    "THAI": "Thaï",
    "ARMENIAN": "Arménien",
    "GEORGIAN": "Géorgien",
    "ETHIOPIC": "Éthiopien",
    "TAMIL": "Tamoul",
    "BENGALI": "Bengali",
    "TELUGU": "Télougou",
}

# %%
def count_alphabet_characters(text):
    script_counts = defaultdict(int)

    for char in text:
        if char.isalpha():  
            try:
                char_name = unicodedata.name(char) 
                script_key = char_name.split()[0]  # Take the first word of Unicode character
                
                if "CJK" in char_name:
                    script_key = "CJK"  # Special case for kanjis
                
                script_name = SCRIPT_MAP.get(script_key, script_key)
                script_counts[script_name] += 1  
                
            except ValueError:
                continue  # If char does not have Unicode name
    
    return dict(script_counts) 


def most_frequent_script(text):
    script_counts = count_alphabet_characters(text) 
    
    if script_counts:  
        most_common_script = max(script_counts.items(), key=lambda x: x[1])  
        return most_common_script  
    else:
        return None  

def add_alphabet_to_label(df):
    for index, row in tqdm(df.iterrows(), total=len(df)): 
        alphabet_most_frequent = most_frequent_script(row['Text']) 
        
        if alphabet_most_frequent:  
            df.at[index, 'Label'] = f"{row['Label']}_{alphabet_most_frequent[0]}" 
    
    return df

# %% [markdown]
# **2.3 Final preprocessing function definition**

# %%
 
def pre_processing(df, remove_espace = True, need_to_clean = True): 
    """
    Utilisation des méthodes de pré-traitement définies auparavant pour rendre le texte propre. 
    """

    if need_to_clean: 
        df['Text'] = df['Text'].apply(cleaning)
    
    if remove_espace: 
        df['Text'] = df['Text'].str.replace(' ', '', regex=False)

    df = add_alphabet_to_label(df)
    
    return df

# %% [markdown]
# **2.4 Util functions definition to diplay results**

# %%
def restore_original_label(label):
    
    return label.split("_")[0]  

def restore_labels(liste):
    new_liste = []
    for element in tqdm(liste): 
        new_liste.append(restore_original_label(element))

    return np.array(new_liste)

# %% [markdown]
# ### **3. First classification approach**
# - TF-IDF vectorizer
# - MultinomialNB as a classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import LabelEncoder
tqdm.pandas()

# %%
train_set, val_set = train_test_split(data_train_without_nan_for_label, test_size=0.1, random_state=42)

train_set_first_version = train_set.copy()
val_set_first_version = val_set.copy()

train_set_first_version = pre_processing(train_set_first_version, remove_espace=False) 
val_set_first_version = pre_processing(val_set_first_version, remove_espace=False)
# Out:
# 100%|██████████| 171089/171089 [00:13<00:00, 12394.74it/s]
# 100%|██████████| 19010/19010 [00:01<00:00, 12648.45it/s]

# %% [markdown]
# **3.1 Model training**

# %%
val_set_first_version.head(5)
# Out:
#          Usage                                               Text       Label
# 128184  Public  apărând din față întrun exercițiu apăsând rolu...   ron_Latin
# 95049   Public  sa kaya vua ko jisu sa volai talega mo kakua n...   fij_Latin
# 170377  Public  אין צוואנציק יאר האט דאס דארף פארוואנדלט אין א...  yid_Hébreu
# 171119  Public  seniň sözüňe gulak assa bu doganyňy gazandygyň...   tuk_Latin
# 62238   Public  ala sma fu grontapu o kon na en fesi dan a o p...   srn_Latin

# %%
x_train = train_set_first_version['Text'].tolist()
y_train = train_set_first_version['Label'].tolist()
x_val = val_set_first_version['Text'].tolist()
y_val = val_set_first_version['Label'].tolist()
y_total = y_train + y_val

# Converting categorical variables to numerical
le = LabelEncoder()
le.fit(y_train)

y_train = le.transform(y_train)
y_val = le.transform(y_val)
label_mapping = dict(zip(le.classes_, range(len(le.classes_))))

# %%
# Pipeline with progression bars
pipe = Pipeline([
        ('tfidf', TfidfVectorizer(analyzer="char", ngram_range=(1, 5), max_features=200000)),
    ('classifier', MultinomialNB(alpha=0.001, fit_prior=False))
])

# Usage 
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', max_features=200000,
#                                  ngram_range=(1, 5))),
#                 ('classifier', MultinomialNB(alpha=0.001, fit_prior=False))])

# %% [markdown]
# **3.2 Evaluation**

# %%
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Computing accuracy for out tuned labels

# %%
predictions = pipe.predict(x_val)
accuracy = accuracy_score(y_val, predictions)
print("Raw predictions accuracy:", accuracy)
# Out:
# Raw predictions accuracy: 0.8514466070489216

# %% [markdown]
# Restore original labels and compute final accuracy

# %%
predicted_labels = le.inverse_transform(predictions)
labels_predict = le.inverse_transform(y_val)

final_pred = restore_labels(predicted_labels)
val_predict = restore_labels(labels_predict)
final_accuracy = accuracy_score(val_predict, final_pred)

print("Final accuracy:", final_accuracy)
# Out:
# 100%|██████████| 19010/19010 [00:00<00:00, 263939.41it/s]
# 100%|██████████| 19010/19010 [00:00<00:00, 965813.74it/s]
# Final accuracy: 0.8524986849026828

# %% [markdown]
# Results analysis

# %%
# Generate the report with class indices
present_classes = np.unique(np.concatenate((y_val, predictions)))
filtered_target_names = [le.classes_[i] for i in present_classes]
report = classification_report(y_val, predictions, target_names=filtered_target_names, output_dict=True)

# Filter out non-class entries and sort ('accuracy', 'macro avg', 'weighted avg')
filtered_report = {label: metrics for label, metrics in report.items() if isinstance(metrics, dict)}
sorted_report = sorted(filtered_report.items(), key=lambda x: x[1]['f1-score'], reverse=True)

print("Classification Report:\n")
for label, metrics in sorted_report:
    print(f"{label}: f1 = {metrics['f1-score']:.2f}, Pre = {metrics['precision']:.2f}, Rec = {metrics['recall']:.2f}, Support = {metrics['support']:0f}")
# Out:
# Classification Report:
#
# abk_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# ahk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# alt_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# aoj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# arn_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# asm_Bengali: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# bem_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 38.000000
# bpy_Bengali: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# bqc_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# bzj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# cab_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# cak_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# chk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# cjk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# csy_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# ctu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# cuk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# div_THAANA: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 39.000000
# djk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# fon_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# gom_Devanagari (Hindi, Sanskrit): f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 40.000000
# guc_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# guj_GUJARATI: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# gym_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# hbo_Hébreu: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# hnj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# hui_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# hus_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# iba_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# iku_CANADIAN: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# ixl_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# kac_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# kal_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# kan_KANNADA: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# kek_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# kjb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 40.000000
# knv_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# kos_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# kpg_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 56.000000
# ksd_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# lhu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 20.000000
# lue_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# luo_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# lus_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# lvs_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# mah_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 2.000000
# mal_MALAYALAM: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# mam_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# mau_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# mco_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# meu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# mgh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# mon_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# mos_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 52.000000
# mps_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# mya_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 2.000000
# mzh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# naq_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 59.000000
# nav_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# nch_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# ncj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 39.000000
# ngu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# nnb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# nyu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 42.000000
# orm_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# ote_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# pan_GURMUKHI: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 52.000000
# pap_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# pls_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 36.000000
# poh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# pon_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 47.000000
# qub_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 2.000000
# qvi_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# rop_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 42.000000
# rug_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# sat_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# sat_OL: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 52.000000
# seh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# srm_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# srn_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# suz_Devanagari (Hindi, Sanskrit): f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# tam_Tamoul: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# tbz_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# tca_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# tdt_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 38.000000
# tlh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# toj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# tok_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# top_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# tso_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# tuc_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 59.000000
# tuk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# tzo_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# uig_Arabe: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 59.000000
# umb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 52.000000
# wal_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# wbm_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# xav_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# yao_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 57.000000
# yap_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# zai_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# kir_Cyrillique: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 62.000000
# sgs_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 61.000000
# krc_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 58.000000
# sah_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 58.000000
# crh_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 55.000000
# kbd_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 55.000000
# roh_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 54.000000
# eus_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 54.000000
# quw_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 54.000000
# yom_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 53.000000
# ikk_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 50.000000
# kjh_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 51.000000
# che_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 50.000000
# kbp_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 49.000000
# kor_Hangul (Coréen): f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 49.000000
# sin_SINHALA: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 48.000000
# hun_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 47.000000
# lua_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 47.000000
# ewe_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 47.000000
# mya_MYANMAR: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 45.000000
# heb_Hébreu: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 44.000000
# csb_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 44.000000
# yid_Hébreu: f1 = 0.99, Pre = 1.00, Rec = 0.97, Support = 39.000000
# kam_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.97, Support = 38.000000
# tha_Thaï: f1 = 0.99, Pre = 0.97, Rec = 1.00, Support = 36.000000
# khm_KHMER: f1 = 0.99, Pre = 1.00, Rec = 0.97, Support = 35.000000
# sag_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 63.000000
# quc_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 61.000000
# mwl_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 58.000000
# isl_Latin: f1 = 0.98, Pre = 0.97, Rec = 1.00, Support = 56.000000
# snd_Arabe: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 56.000000
# jbo_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 54.000000
# acr_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 52.000000
# fij_Latin: f1 = 0.98, Pre = 0.96, Rec = 1.00, Support = 50.000000
# vol_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 52.000000
# gom_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 49.000000
# kmb_Latin: f1 = 0.98, Pre = 0.96, Rec = 1.00, Support = 47.000000
# xmf_Géorgien: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 49.000000
# hmo_Latin: f1 = 0.98, Pre = 0.96, Rec = 1.00, Support = 46.000000
# dtp_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 47.000000
# glv_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 47.000000
# quh_Latin: f1 = 0.98, Pre = 0.95, Rec = 1.00, Support = 40.000000
# vie_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 40.000000
# oss_Cyrillique: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 58.000000
# lit_Latin: f1 = 0.97, Pre = 0.96, Rec = 0.98, Support = 55.000000
# pms_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 38.000000
# fur_Latin: f1 = 0.97, Pre = 0.98, Rec = 0.96, Support = 52.000000
# ilo_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 53.000000
# frr_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 50.000000
# ndo_Latin: f1 = 0.97, Pre = 0.96, Rec = 0.98, Support = 48.000000
# tur_Latin: f1 = 0.97, Pre = 0.96, Rec = 0.98, Support = 48.000000
# diq_Latin: f1 = 0.97, Pre = 0.98, Rec = 0.96, Support = 47.000000
# kat_Géorgien: f1 = 0.97, Pre = 0.94, Rec = 1.00, Support = 45.000000
# lin_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 48.000000
# sme_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 48.000000
# tpi_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 48.000000
# mkd_Cyrillique: f1 = 0.97, Pre = 0.95, Rec = 0.98, Support = 59.000000
# eml_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.93, Support = 59.000000
# bul_Cyrillique: f1 = 0.96, Pre = 0.98, Rec = 0.95, Support = 43.000000
# azb_Arabe: f1 = 0.96, Pre = 0.96, Rec = 0.96, Support = 56.000000
# kon_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.93, Support = 58.000000
# swe_Latin: f1 = 0.96, Pre = 0.95, Rec = 0.98, Support = 54.000000
# cat_Latin: f1 = 0.96, Pre = 0.95, Rec = 0.97, Support = 40.000000
# kik_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.93, Support = 42.000000
# mar_Devanagari (Hindi, Sanskrit): f1 = 0.96, Pre = 0.97, Rec = 0.95, Support = 41.000000
# slv_Latin: f1 = 0.96, Pre = 0.97, Rec = 0.95, Support = 41.000000
# kea_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 53.000000
# tum_Latin: f1 = 0.96, Pre = 0.96, Rec = 0.96, Support = 51.000000
# jam_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 64.000000
# bam_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 51.000000
# tyv_Cyrillique: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 63.000000
# cym_Latin: f1 = 0.96, Pre = 0.96, Rec = 0.96, Support = 48.000000
# fin_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 49.000000
# amh_Éthiopien: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 49.000000
# dyu_Latin: f1 = 0.96, Pre = 0.92, Rec = 1.00, Support = 55.000000
# lfn_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 47.000000
# ell_Grec: f1 = 0.96, Pre = 0.92, Rec = 1.00, Support = 54.000000
# grc_Grec: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 59.000000
# kaz_Cyrillique: f1 = 0.95, Pre = 1.00, Rec = 0.91, Support = 46.000000
# tir_Éthiopien: f1 = 0.95, Pre = 0.91, Rec = 1.00, Support = 41.000000
# ssw_Latin: f1 = 0.95, Pre = 0.97, Rec = 0.94, Support = 65.000000
# yor_Latin: f1 = 0.95, Pre = 1.00, Rec = 0.91, Support = 54.000000
# lao_LAO: f1 = 0.95, Pre = 0.93, Rec = 0.97, Support = 40.000000
# ace_Latin: f1 = 0.95, Pre = 0.98, Rec = 0.92, Support = 52.000000
# hye_Arménien: f1 = 0.95, Pre = 0.92, Rec = 0.98, Support = 49.000000
# ido_Latin: f1 = 0.95, Pre = 0.95, Rec = 0.95, Support = 40.000000
# lug_Latin: f1 = 0.95, Pre = 0.96, Rec = 0.94, Support = 50.000000
# new_Devanagari (Hindi, Sanskrit): f1 = 0.95, Pre = 0.98, Rec = 0.92, Support = 59.000000
# vep_Latin: f1 = 0.95, Pre = 1.00, Rec = 0.90, Support = 50.000000
# slk_Latin: f1 = 0.94, Pre = 0.94, Rec = 0.94, Support = 54.000000
# udm_Cyrillique: f1 = 0.94, Pre = 0.98, Rec = 0.91, Support = 46.000000
# rmy_Latin: f1 = 0.94, Pre = 0.98, Rec = 0.91, Support = 54.000000
# ach_Latin: f1 = 0.94, Pre = 0.89, Rec = 1.00, Support = 8.000000
# bre_Latin: f1 = 0.94, Pre = 0.96, Rec = 0.92, Support = 60.000000
# chv_Cyrillique: f1 = 0.94, Pre = 1.00, Rec = 0.89, Support = 44.000000
# epo_Latin: f1 = 0.94, Pre = 0.97, Rec = 0.91, Support = 43.000000
# szl_Latin: f1 = 0.94, Pre = 0.97, Rec = 0.91, Support = 34.000000
# gug_Latin: f1 = 0.94, Pre = 0.90, Rec = 0.98, Support = 55.000000
# kom_Cyrillique: f1 = 0.94, Pre = 0.96, Rec = 0.92, Support = 50.000000
# gla_Latin: f1 = 0.94, Pre = 0.98, Rec = 0.90, Support = 50.000000
# bis_Latin: f1 = 0.94, Pre = 0.98, Rec = 0.90, Support = 58.000000
# mhr_Cyrillique: f1 = 0.94, Pre = 0.93, Rec = 0.95, Support = 55.000000
# ful_Latin: f1 = 0.93, Pre = 1.00, Rec = 0.88, Support = 49.000000
# aln_Latin: f1 = 0.93, Pre = 0.91, Rec = 0.96, Support = 52.000000
# fao_Latin: f1 = 0.93, Pre = 0.96, Rec = 0.91, Support = 53.000000
# ces_Latin: f1 = 0.93, Pre = 0.95, Rec = 0.91, Support = 45.000000
# arg_Latin: f1 = 0.93, Pre = 0.95, Rec = 0.92, Support = 59.000000
# ibo_Latin: f1 = 0.93, Pre = 1.00, Rec = 0.87, Support = 53.000000
# san_Devanagari (Hindi, Sanskrit): f1 = 0.93, Pre = 0.88, Rec = 0.98, Support = 59.000000
# afr_Latin: f1 = 0.93, Pre = 0.94, Rec = 0.91, Support = 56.000000
# kaa_Latin: f1 = 0.93, Pre = 0.98, Rec = 0.88, Support = 58.000000
# arz_Arabe: f1 = 0.92, Pre = 0.96, Rec = 0.89, Support = 55.000000
# npi_Devanagari (Hindi, Sanskrit): f1 = 0.92, Pre = 0.92, Rec = 0.92, Support = 66.000000
# crh_Cyrillique: f1 = 0.92, Pre = 1.00, Rec = 0.86, Support = 42.000000
# som_Latin: f1 = 0.92, Pre = 0.98, Rec = 0.88, Support = 48.000000
# pag_Latin: f1 = 0.92, Pre = 1.00, Rec = 0.85, Support = 55.000000
# tah_Latin: f1 = 0.92, Pre = 1.00, Rec = 0.85, Support = 48.000000
# ksh_Latin: f1 = 0.92, Pre = 0.94, Rec = 0.91, Support = 64.000000
# fry_Latin: f1 = 0.92, Pre = 0.94, Rec = 0.90, Support = 51.000000
# gle_Latin: f1 = 0.92, Pre = 0.88, Rec = 0.96, Support = 53.000000
# pis_Latin: f1 = 0.92, Pre = 0.85, Rec = 1.00, Support = 17.000000
# hsb_Latin: f1 = 0.92, Pre = 0.98, Rec = 0.87, Support = 52.000000
# ton_Latin: f1 = 0.92, Pre = 0.92, Rec = 0.92, Support = 49.000000
# pus_Arabe: f1 = 0.92, Pre = 0.96, Rec = 0.88, Support = 57.000000
# lij_Latin: f1 = 0.92, Pre = 0.91, Rec = 0.92, Support = 53.000000
# wol_Latin: f1 = 0.92, Pre = 0.93, Rec = 0.90, Support = 42.000000
# ven_Latin: f1 = 0.91, Pre = 1.00, Rec = 0.84, Support = 51.000000
# ile_Latin: f1 = 0.91, Pre = 0.92, Rec = 0.91, Support = 53.000000
# mzn_Arabe: f1 = 0.91, Pre = 0.95, Rec = 0.88, Support = 48.000000
# pol_Latin: f1 = 0.91, Pre = 0.84, Rec = 1.00, Support = 46.000000
# jpn_Katakana (Japonais): f1 = 0.91, Pre = 0.83, Rec = 1.00, Support = 10.000000
# kaa_Cyrillique: f1 = 0.91, Pre = 0.98, Rec = 0.85, Support = 59.000000
# vls_Latin: f1 = 0.91, Pre = 0.88, Rec = 0.94, Support = 53.000000
# grn_Latin: f1 = 0.91, Pre = 0.96, Rec = 0.86, Support = 50.000000
# por_Latin: f1 = 0.91, Pre = 0.90, Rec = 0.91, Support = 47.000000
# mai_Devanagari (Hindi, Sanskrit): f1 = 0.90, Pre = 0.93, Rec = 0.88, Support = 59.000000
# gcf_Latin: f1 = 0.90, Pre = 1.00, Rec = 0.82, Support = 17.000000
# lim_Latin: f1 = 0.90, Pre = 0.91, Rec = 0.89, Support = 47.000000
# gsw_Latin: f1 = 0.90, Pre = 0.89, Rec = 0.91, Support = 35.000000
# pnb_Arabe: f1 = 0.90, Pre = 0.92, Rec = 0.88, Support = 50.000000
# min_Latin: f1 = 0.90, Pre = 0.90, Rec = 0.90, Support = 48.000000
# hmn_Latin: f1 = 0.89, Pre = 1.00, Rec = 0.80, Support = 51.000000
# ext_Latin: f1 = 0.89, Pre = 0.90, Rec = 0.88, Support = 50.000000
# tat_Cyrillique: f1 = 0.89, Pre = 0.81, Rec = 0.98, Support = 53.000000
# ukr_Cyrillique: f1 = 0.89, Pre = 0.81, Rec = 0.98, Support = 45.000000
# zlm_Latin: f1 = 0.89, Pre = 0.88, Rec = 0.90, Support = 70.000000
# myv_Cyrillique: f1 = 0.89, Pre = 0.84, Rec = 0.94, Support = 63.000000
# ron_Latin: f1 = 0.89, Pre = 0.84, Rec = 0.94, Support = 50.000000
# tls_Latin: f1 = 0.89, Pre = 0.96, Rec = 0.83, Support = 52.000000
# quy_Latin: f1 = 0.88, Pre = 0.79, Rec = 1.00, Support = 45.000000
# pfl_Latin: f1 = 0.88, Pre = 0.88, Rec = 0.88, Support = 41.000000
# hne_Devanagari (Hindi, Sanskrit): f1 = 0.88, Pre = 0.91, Rec = 0.85, Support = 59.000000
# lmo_Latin: f1 = 0.87, Pre = 0.84, Rec = 0.90, Support = 41.000000
# nap_Latin: f1 = 0.87, Pre = 0.92, Rec = 0.82, Support = 56.000000
# ceb_Latin: f1 = 0.87, Pre = 0.90, Rec = 0.84, Support = 43.000000
# rap_Latin: f1 = 0.86, Pre = 0.95, Rec = 0.79, Support = 24.000000
# nno_Latin: f1 = 0.86, Pre = 0.79, Rec = 0.95, Support = 39.000000
# bod_TIBETAN: f1 = 0.86, Pre = 0.78, Rec = 0.96, Support = 45.000000
# deu_Latin: f1 = 0.86, Pre = 0.81, Rec = 0.91, Support = 47.000000
# bih_Devanagari (Hindi, Sanskrit): f1 = 0.86, Pre = 0.81, Rec = 0.91, Support = 46.000000
# hif_Latin: f1 = 0.86, Pre = 0.81, Rec = 0.91, Support = 43.000000
# mon_Latin: f1 = 0.85, Pre = 0.92, Rec = 0.80, Support = 44.000000
# weighted avg: f1 = 0.85, Pre = 0.87, Rec = 0.85, Support = 19010.000000
# fra_Latin: f1 = 0.85, Pre = 0.78, Rec = 0.93, Support = 46.000000
# glg_Latin: f1 = 0.85, Pre = 0.84, Rec = 0.86, Support = 49.000000
# dan_Latin: f1 = 0.85, Pre = 0.90, Rec = 0.80, Support = 45.000000
# lat_Latin: f1 = 0.85, Pre = 0.80, Rec = 0.90, Support = 49.000000
# yue_Kanji (Chinois, Japonais, Coréen): f1 = 0.85, Pre = 0.89, Rec = 0.81, Support = 68.000000
# nds_Latin: f1 = 0.84, Pre = 0.80, Rec = 0.89, Support = 44.000000
# dzo_TIBETAN: f1 = 0.83, Pre = 0.91, Rec = 0.77, Support = 52.000000
# hau_Latin: f1 = 0.83, Pre = 0.78, Rec = 0.90, Support = 50.000000
# macro avg: f1 = 0.83, Pre = 0.85, Rec = 0.83, Support = 19010.000000
# bsb_Latin: f1 = 0.83, Pre = 0.87, Rec = 0.80, Support = 49.000000
# bar_Latin: f1 = 0.83, Pre = 0.82, Rec = 0.84, Support = 55.000000
# nld_Latin: f1 = 0.83, Pre = 0.80, Rec = 0.85, Support = 48.000000
# pcd_Latin: f1 = 0.82, Pre = 0.77, Rec = 0.87, Support = 55.000000
# lzh_Kanji (Chinois, Japonais, Coréen): f1 = 0.82, Pre = 0.74, Rec = 0.91, Support = 58.000000
# hrx_Latin: f1 = 0.81, Pre = 1.00, Rec = 0.69, Support = 16.000000
# zea_Latin: f1 = 0.81, Pre = 0.83, Rec = 0.80, Support = 44.000000
# bak_Cyrillique: f1 = 0.81, Pre = 0.95, Rec = 0.71, Support = 58.000000
# rue_Cyrillique: f1 = 0.81, Pre = 0.72, Rec = 0.93, Support = 44.000000
# swc_Latin: f1 = 0.81, Pre = 0.88, Rec = 0.75, Support = 57.000000
# jpn_Hiragana (Japonais): f1 = 0.81, Pre = 0.68, Rec = 1.00, Support = 19.000000
# mlt_Latin: f1 = 0.80, Pre = 0.85, Rec = 0.76, Support = 46.000000
# hat_Latin: f1 = 0.80, Pre = 0.90, Rec = 0.73, Support = 51.000000
# nso_Latin: f1 = 0.80, Pre = 0.79, Rec = 0.82, Support = 45.000000
# pcm_Latin: f1 = 0.80, Pre = 0.74, Rec = 0.88, Support = 67.000000
# ast_Latin: f1 = 0.80, Pre = 0.72, Rec = 0.90, Support = 49.000000
# bjn_Latin: f1 = 0.80, Pre = 0.81, Rec = 0.79, Support = 48.000000
# uzb_Latin: f1 = 0.80, Pre = 0.75, Rec = 0.84, Support = 58.000000
# ayr_Latin: f1 = 0.79, Pre = 0.69, Rec = 0.91, Support = 45.000000
# plt_Latin: f1 = 0.79, Pre = 1.00, Rec = 0.65, Support = 65.000000
# uig_Latin: f1 = 0.78, Pre = 0.94, Rec = 0.67, Support = 46.000000
# kur_Latin: f1 = 0.78, Pre = 0.68, Rec = 0.91, Support = 57.000000
# smo_Latin: f1 = 0.78, Pre = 0.92, Rec = 0.68, Support = 50.000000
# scn_Latin: f1 = 0.78, Pre = 0.80, Rec = 0.76, Support = 63.000000
# oci_Latin: f1 = 0.78, Pre = 0.85, Rec = 0.72, Support = 46.000000
# jav_Latin: f1 = 0.77, Pre = 0.77, Rec = 0.77, Support = 48.000000
# nep_Devanagari (Hindi, Sanskrit): f1 = 0.76, Pre = 0.78, Rec = 0.74, Support = 43.000000
# haw_Latin: f1 = 0.76, Pre = 0.91, Rec = 0.65, Support = 46.000000
# prs_Arabe: f1 = 0.76, Pre = 0.67, Rec = 0.87, Support = 54.000000
# est_Latin: f1 = 0.76, Pre = 0.83, Rec = 0.70, Support = 56.000000
# srd_Latin: f1 = 0.76, Pre = 0.90, Rec = 0.65, Support = 57.000000
# bew_Cyrillique: f1 = 0.75, Pre = 0.73, Rec = 0.78, Support = 51.000000
# ekk_Latin: f1 = 0.75, Pre = 0.69, Rec = 0.83, Support = 42.000000
# kat_Latin: f1 = 0.75, Pre = 0.72, Rec = 0.79, Support = 56.000000
# mlg_Latin: f1 = 0.75, Pre = 0.66, Rec = 0.87, Support = 54.000000
# que_Latin: f1 = 0.75, Pre = 0.97, Rec = 0.61, Support = 49.000000
# tsn_Latin: f1 = 0.74, Pre = 0.74, Rec = 0.74, Support = 46.000000
# cmn_Kanji (Chinois, Japonais, Coréen): f1 = 0.74, Pre = 0.63, Rec = 0.89, Support = 35.000000
# kab_Latin: f1 = 0.74, Pre = 0.63, Rec = 0.89, Support = 47.000000
# ina_Latin: f1 = 0.73, Pre = 0.72, Rec = 0.75, Support = 48.000000
# ber_Latin: f1 = 0.72, Pre = 0.88, Rec = 0.61, Support = 57.000000
# cbk_Latin: f1 = 0.72, Pre = 0.73, Rec = 0.71, Support = 49.000000
# nya_Latin: f1 = 0.72, Pre = 0.84, Rec = 0.63, Support = 49.000000
# hbs_Cyrillique: f1 = 0.72, Pre = 0.66, Rec = 0.79, Support = 53.000000
# aka_Latin: f1 = 0.71, Pre = 0.75, Rec = 0.67, Support = 49.000000
# bak_Latin: f1 = 0.71, Pre = 0.69, Rec = 0.73, Support = 48.000000
# kmr_Latin: f1 = 0.71, Pre = 0.97, Rec = 0.56, Support = 54.000000
# bel_Cyrillique: f1 = 0.70, Pre = 0.76, Rec = 0.65, Support = 52.000000
# nbl_Latin: f1 = 0.70, Pre = 0.56, Rec = 0.94, Support = 36.000000
# wuu_Kanji (Chinois, Japonais, Coréen): f1 = 0.69, Pre = 0.69, Rec = 0.70, Support = 47.000000
# jpn_Kanji (Chinois, Japonais, Coréen): f1 = 0.69, Pre = 1.00, Rec = 0.53, Support = 17.000000
# hin_Devanagari (Hindi, Sanskrit): f1 = 0.69, Pre = 0.64, Rec = 0.74, Support = 50.000000
# wln_Latin: f1 = 0.68, Pre = 0.70, Rec = 0.66, Support = 50.000000
# ltz_Latin: f1 = 0.68, Pre = 0.60, Rec = 0.79, Support = 43.000000
# spa_Latin: f1 = 0.68, Pre = 0.62, Rec = 0.75, Support = 48.000000
# twi_Latin: f1 = 0.68, Pre = 0.67, Rec = 0.69, Support = 52.000000
# dzo_Latin: f1 = 0.67, Pre = 1.00, Rec = 0.50, Support = 4.000000
# hil_Latin: f1 = 0.67, Pre = 0.80, Rec = 0.57, Support = 7.000000
# mri_Latin: f1 = 0.67, Pre = 0.84, Rec = 0.55, Support = 47.000000
# run_Latin: f1 = 0.66, Pre = 0.57, Rec = 0.80, Support = 49.000000
# arb_Arabe: f1 = 0.66, Pre = 0.56, Rec = 0.80, Support = 54.000000
# xho_Latin: f1 = 0.65, Pre = 0.90, Rec = 0.51, Support = 51.000000
# ban_Latin: f1 = 0.65, Pre = 0.73, Rec = 0.58, Support = 57.000000
# gor_Latin: f1 = 0.64, Pre = 0.95, Rec = 0.49, Support = 37.000000
# glk_Arabe: f1 = 0.64, Pre = 0.68, Rec = 0.60, Support = 45.000000
# war_Latin: f1 = 0.64, Pre = 0.63, Rec = 0.64, Support = 42.000000
# ckb_Arabe: f1 = 0.63, Pre = 0.51, Rec = 0.83, Support = 46.000000
# aym_Latin: f1 = 0.62, Pre = 0.89, Rec = 0.48, Support = 50.000000
# ita_Latin: f1 = 0.62, Pre = 0.56, Rec = 0.70, Support = 43.000000
# tgl_Latin: f1 = 0.61, Pre = 0.68, Rec = 0.56, Support = 61.000000
# urd_Arabe: f1 = 0.61, Pre = 0.49, Rec = 0.80, Support = 50.000000
# sqi_Latin: f1 = 0.60, Pre = 0.52, Rec = 0.72, Support = 40.000000
# swa_Latin: f1 = 0.60, Pre = 0.59, Rec = 0.60, Support = 48.000000
# ory_ORIYA: f1 = 0.59, Pre = 0.56, Rec = 0.63, Support = 38.000000
# aze_Latin: f1 = 0.59, Pre = 0.58, Rec = 0.59, Support = 49.000000
# pes_Arabe: f1 = 0.59, Pre = 0.63, Rec = 0.55, Support = 44.000000
# hbs_Latin: f1 = 0.58, Pre = 0.44, Rec = 0.86, Support = 49.000000
# aze_Arabe: f1 = 0.58, Pre = 0.58, Rec = 0.59, Support = 63.000000
# swh_Latin: f1 = 0.58, Pre = 0.55, Rec = 0.61, Support = 46.000000
# srp_Cyrillique: f1 = 0.57, Pre = 0.66, Rec = 0.51, Support = 45.000000
# nob_Latin: f1 = 0.57, Pre = 0.54, Rec = 0.61, Support = 49.000000
# ori_ORIYA: f1 = 0.57, Pre = 0.61, Rec = 0.54, Support = 41.000000
# sot_Latin: f1 = 0.57, Pre = 0.67, Rec = 0.50, Support = 60.000000
# sun_Latin: f1 = 0.57, Pre = 0.61, Rec = 0.53, Support = 43.000000
# azj_Latin: f1 = 0.56, Pre = 0.57, Rec = 0.55, Support = 49.000000
# bik_Latin: f1 = 0.55, Pre = 0.53, Rec = 0.56, Support = 43.000000
# lao_Latin: f1 = 0.55, Pre = 0.60, Rec = 0.50, Support = 6.000000
# zho_Kanji (Chinois, Japonais, Coréen): f1 = 0.54, Pre = 0.76, Rec = 0.42, Support = 62.000000
# srp_Latin: f1 = 0.54, Pre = 0.60, Rec = 0.49, Support = 55.000000
# pam_Latin: f1 = 0.53, Pre = 0.48, Rec = 0.59, Support = 46.000000
# mad_Latin: f1 = 0.53, Pre = 0.53, Rec = 0.53, Support = 55.000000
# bcl_Latin: f1 = 0.53, Pre = 0.51, Rec = 0.54, Support = 57.000000
# guj_Devanagari (Hindi, Sanskrit): f1 = 0.52, Pre = 0.54, Rec = 0.51, Support = 53.000000
# tat_Latin: f1 = 0.52, Pre = 0.76, Rec = 0.40, Support = 48.000000
# cos_Latin: f1 = 0.52, Pre = 0.64, Rec = 0.43, Support = 53.000000
# sna_Latin: f1 = 0.51, Pre = 0.89, Rec = 0.35, Support = 48.000000
# nor_Latin: f1 = 0.51, Pre = 0.54, Rec = 0.48, Support = 46.000000
# khm_Latin: f1 = 0.50, Pre = 0.33, Rec = 1.00, Support = 1.000000
# san_Latin: f1 = 0.50, Pre = 0.50, Rec = 0.50, Support = 6.000000
# vec_Latin: f1 = 0.49, Pre = 0.41, Rec = 0.62, Support = 39.000000
# kur_Arabe: f1 = 0.48, Pre = 0.72, Rec = 0.36, Support = 58.000000
# tgk_Cyrillique: f1 = 0.47, Pre = 0.61, Rec = 0.39, Support = 49.000000
# tuk_Cyrillique: f1 = 0.47, Pre = 0.37, Rec = 0.65, Support = 17.000000
# sco_Latin: f1 = 0.47, Pre = 0.34, Rec = 0.75, Support = 68.000000
# ara_Arabe: f1 = 0.47, Pre = 0.35, Rec = 0.70, Support = 54.000000
# uzn_Cyrillique: f1 = 0.46, Pre = 0.50, Rec = 0.43, Support = 53.000000
# kin_Latin: f1 = 0.46, Pre = 0.45, Rec = 0.47, Support = 40.000000
# apc_Arabe: f1 = 0.46, Pre = 0.42, Rec = 0.52, Support = 52.000000
# zul_Latin: f1 = 0.46, Pre = 0.63, Rec = 0.36, Support = 47.000000
# ary_Arabe: f1 = 0.46, Pre = 0.47, Rec = 0.44, Support = 54.000000
# nde_Latin: f1 = 0.46, Pre = 0.50, Rec = 0.42, Support = 43.000000
# tgk_Latin: f1 = 0.45, Pre = 0.53, Rec = 0.40, Support = 48.000000
# fas_Arabe: f1 = 0.44, Pre = 0.40, Rec = 0.50, Support = 44.000000
# guj_Latin: f1 = 0.44, Pre = 0.50, Rec = 0.40, Support = 5.000000
# fil_Latin: f1 = 0.42, Pre = 0.40, Rec = 0.44, Support = 39.000000
# acm_Arabe: f1 = 0.42, Pre = 0.58, Rec = 0.33, Support = 55.000000
# ind_Latin: f1 = 0.41, Pre = 0.37, Rec = 0.47, Support = 36.000000
# als_Latin: f1 = 0.41, Pre = 0.57, Rec = 0.33, Support = 40.000000
# enm_Latin: f1 = 0.40, Pre = 0.50, Rec = 0.33, Support = 3.000000
# hau_Arabe: f1 = 0.39, Pre = 0.67, Rec = 0.27, Support = 66.000000
# eng_Latin: f1 = 0.38, Pre = 0.26, Rec = 0.72, Support = 54.000000
# ajp_Arabe: f1 = 0.38, Pre = 0.31, Rec = 0.49, Support = 35.000000
# msa_Latin: f1 = 0.38, Pre = 0.32, Rec = 0.46, Support = 52.000000
# zsm_Latin: f1 = 0.37, Pre = 0.34, Rec = 0.40, Support = 40.000000
# uzb_Cyrillique: f1 = 0.32, Pre = 0.26, Rec = 0.43, Support = 47.000000
# hin_Latin: f1 = 0.32, Pre = 0.24, Rec = 0.46, Support = 48.000000
# afb_Arabe: f1 = 0.30, Pre = 0.34, Rec = 0.27, Support = 48.000000
# tgk_Arabe: f1 = 0.28, Pre = 0.42, Rec = 0.21, Support = 47.000000
# bos_Latin: f1 = 0.23, Pre = 0.31, Rec = 0.18, Support = 50.000000
# som_Arabe: f1 = 0.23, Pre = 0.78, Rec = 0.13, Support = 53.000000
# hrv_Latin: f1 = 0.17, Pre = 0.23, Rec = 0.14, Support = 36.000000
# hyw_Arménien: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 4.000000
# ksw_MYANMAR: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# mai_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# ngl_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# pus_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 0.000000
# quz_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# sin_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# tha_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Extract labels that have lower than 0.5 F1-score
labels_to_improve = {label: metrics for label, metrics in filtered_report.items() if metrics['f1-score'] < 0.5}
labels_to_improve
# Out:
# {np.str_('acm_Arabe'): {'precision': 0.5806451612903226,
#   'recall': 0.32727272727272727,
#   'f1-score': 0.4186046511627907,
#   'support': 55.0},
#  np.str_('afb_Arabe'): {'precision': 0.34210526315789475,
#   'recall': 0.2708333333333333,
#   'f1-score': 0.3023255813953488,
#   'support': 48.0},
#  np.str_('ajp_Arabe'): {'precision': 0.3090909090909091,
#   'recall': 0.4857142857142857,
#   'f1-score': 0.37777777777777777,
#   'support': 35.0},
#  np.str_('als_Latin'): {'precision': 0.5652173913043478,
#   'recall': 0.325,
#   'f1-score': 0.4126984126984127,
#   'support': 40.0},
#  np.str_('apc_Arabe'): {'precision': 0.4153846153846154,
#   'recall': 0.5192307692307693,
#   'f1-score': 0.46153846153846156,
#   'support': 52.0},
#  np.str_('ara_Arabe'): {'precision': 0.3486238532110092,
#   'recall': 0.7037037037037037,
#   'f1-score': 0.4662576687116564,
#   'support': 54.0},
#  np.str_('ary_Arabe'): {'precision': 0.47058823529411764,
#   'recall': 0.4444444444444444,
#   'f1-score': 0.45714285714285713,
#   'support': 54.0},
#  np.str_('bos_Latin'): {'precision': 0.3103448275862069,
#   'recall': 0.18,
#   'f1-score': 0.22784810126582278,
#   'support': 50.0},
#  np.str_('eng_Latin'): {'precision': 0.2565789473684211,
#   'recall': 0.7222222222222222,
#   'f1-score': 0.3786407766990291,
#   'support': 54.0},
#  np.str_('enm_Latin'): {'precision': 0.5,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.4,
#   'support': 3.0},
#  np.str_('fas_Arabe'): {'precision': 0.4,
#   'recall': 0.5,
#   'f1-score': 0.4444444444444444,
#   'support': 44.0},
#  np.str_('fil_Latin'): {'precision': 0.40476190476190477,
#   'recall': 0.4358974358974359,
#   'f1-score': 0.41975308641975306,
#   'support': 39.0},
#  np.str_('guj_Latin'): {'precision': 0.5,
#   'recall': 0.4,
#   'f1-score': 0.4444444444444444,
#   'support': 5.0},
#  np.str_('hau_Arabe'): {'precision': 0.6666666666666666,
#   'recall': 0.2727272727272727,
#   'f1-score': 0.3870967741935484,
#   'support': 66.0},
#  np.str_('hin_Latin'): {'precision': 0.24444444444444444,
#   'recall': 0.4583333333333333,
#   'f1-score': 0.3188405797101449,
#   'support': 48.0},
#  np.str_('hrv_Latin'): {'precision': 0.22727272727272727,
#   'recall': 0.1388888888888889,
#   'f1-score': 0.1724137931034483,
#   'support': 36.0},
#  np.str_('hyw_Arménien'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  np.str_('ind_Latin'): {'precision': 0.3695652173913043,
#   'recall': 0.4722222222222222,
#   'f1-score': 0.4146341463414634,
#   'support': 36.0},
#  np.str_('kin_Latin'): {'precision': 0.4523809523809524,
#   'recall': 0.475,
#   'f1-score': 0.4634146341463415,
#   'support': 40.0},
#  np.str_('ksw_MYANMAR'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  np.str_('kur_Arabe'): {'precision': 0.7241379310344828,
#   'recall': 0.3620689655172414,
#   'f1-score': 0.4827586206896552,
#   'support': 58.0},
#  np.str_('mai_Latin'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  np.str_('msa_Latin'): {'precision': 0.3157894736842105,
#   'recall': 0.46153846153846156,
#   'f1-score': 0.375,
#   'support': 52.0},
#  np.str_('nde_Latin'): {'precision': 0.5,
#   'recall': 0.4186046511627907,
#   'f1-score': 0.45569620253164556,
#   'support': 43.0},
#  np.str_('ngl_Latin'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  np.str_('pus_Latin'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 0.0},
#  np.str_('quz_Latin'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  np.str_('sco_Latin'): {'precision': 0.34,
#   'recall': 0.75,
#   'f1-score': 0.46788990825688076,
#   'support': 68.0},
#  np.str_('sin_Latin'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  np.str_('som_Arabe'): {'precision': 0.7777777777777778,
#   'recall': 0.1320754716981132,
#   'f1-score': 0.22580645161290322,
#   'support': 53.0},
#  np.str_('tgk_Arabe'): {'precision': 0.4166666666666667,
#   'recall': 0.2127659574468085,
#   'f1-score': 0.28169014084507044,
#   'support': 47.0},
#  np.str_('tgk_Cyrillique'): {'precision': 0.6129032258064516,
#   'recall': 0.3877551020408163,
#   'f1-score': 0.475,
#   'support': 49.0},
#  np.str_('tgk_Latin'): {'precision': 0.5277777777777778,
#   'recall': 0.3958333333333333,
#   'f1-score': 0.4523809523809524,
#   'support': 48.0},
#  np.str_('tha_Latin'): {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  np.str_('tuk_Cyrillique'): {'precision': 0.36666666666666664,
#   'recall': 0.6470588235294118,
#   'f1-score': 0.46808510638297873,
#   'support': 17.0},
#  np.str_('uzb_Cyrillique'): {'precision': 0.2597402597402597,
#   'recall': 0.425531914893617,
#   'f1-score': 0.3225806451612903,
#   'support': 47.0},
#  np.str_('uzn_Cyrillique'): {'precision': 0.5,
#   'recall': 0.4339622641509434,
#   'f1-score': 0.46464646464646464,
#   'support': 53.0},
#  np.str_('vec_Latin'): {'precision': 0.41379310344827586,
#   'recall': 0.6153846153846154,
#   'f1-score': 0.4948453608247423,
#   'support': 39.0},
#  np.str_('zsm_Latin'): {'precision': 0.3404255319148936,
#   'recall': 0.4,
#   'f1-score': 0.367816091954023,
#   'support': 40.0},
#  np.str_('zul_Latin'): {'precision': 0.6296296296296297,
#   'recall': 0.3617021276595745,
#   'f1-score': 0.4594594594594595,
#   'support': 47.0}}

# %% [markdown]
# ### **4. Second approach**
# - SentencePiece as a tokenizer
# - TF-IDF vectorizer
# - MultinomialNB as a classifier

# %% [markdown]
# **4.1 SentencePiece training**

# %%
import sentencepiece as spm

# %% [markdown]
# Raw txt file generation to train SentencePiece

# %%
corpus_path = "corpus_multilingue.txt" 
data_train_preprocessed_for_corpus = data_train.copy()
data_train_preprocessed_for_corpus = pre_processing(data_train_preprocessed_for_corpus, remove_espace=False)
data_train_preprocessed_for_corpus["Text"].dropna().to_csv(corpus_path, index=False, header=False, sep="\n")

print(f"Saved corpus : {corpus_path}, with {len(data_train)} sentences.")
# Out:
# 100%|██████████| 190599/190599 [00:14<00:00, 12851.58it/s]
# Saved corpus : corpus_multilingue.txt, with 190599 sentences.

# %% [markdown]
# Model loading and training

# %%
spm.SentencePieceTrainer.Train(
    input='./corpus_multilingue.txt',  
    model_prefix='sp_model',
    vocab_size=60000,  
    character_coverage=1.0,  
    model_type='unigram'  
)

sp = spm.SentencePieceProcessor(model_file='sp_model.model')
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./corpus_multilingue.txt
#   input_format:
#   model_prefix: sp_model
#   model_type: UNIGRAM
#   vocab_size: 60000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: ./corpus_multilingue.txt
# trainer_interface.cc(380) LOG(WARNING) Found too long line (4363 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 190421 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 178 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=26027198
# trainer_interface.cc(560) LOG(INFO) Alphabet size=8558
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 190421 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=12303137
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 1008558 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 190421
# trainer_interface.cc(609) LOG(INFO) Done! 1108119
# unigram_model_trainer.cc(602) LOG(INFO) Using 1108119 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=558877 obj=17.4577 num_tokens=2624531 num_tokens/piece=4.69608
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=481688 obj=16.2142 num_tokens=2638776 num_tokens/piece=5.47819
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=360984 obj=16.2329 num_tokens=2718022 num_tokens/piece=7.52948
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=360201 obj=16.1747 num_tokens=2719808 num_tokens/piece=7.55081
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=270081 obj=16.364 num_tokens=2849142 num_tokens/piece=10.5492
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=270018 obj=16.2952 num_tokens=2850182 num_tokens/piece=10.5555
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=202503 obj=16.6078 num_tokens=3006355 num_tokens/piece=14.846
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=202492 obj=16.5142 num_tokens=3007668 num_tokens/piece=14.8533
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=151869 obj=16.9066 num_tokens=3172942 num_tokens/piece=20.8926
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=151868 obj=16.8042 num_tokens=3173692 num_tokens/piece=20.8977
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=113900 obj=17.254 num_tokens=3344325 num_tokens/piece=29.3619
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=113900 obj=17.1512 num_tokens=3345143 num_tokens/piece=29.3691
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=85425 obj=17.651 num_tokens=3521664 num_tokens/piece=41.2252
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=85424 obj=17.5465 num_tokens=3522692 num_tokens/piece=41.2377
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=66000 obj=18.0291 num_tokens=3685929 num_tokens/piece=55.8474
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=66000 obj=17.9329 num_tokens=3687266 num_tokens/piece=55.8677
# trainer_interface.cc(687) LOG(INFO) Saving model: sp_model.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: sp_model.vocab

# %% [markdown]
# **4.2 Preprocessing applying tokenization**

# %%
def sentencepiece_tokenize(text):
    """Tokenise un texte en sous-mots avec SentencePiece"""
    
    return ' '.join(sp.encode(text, out_type=str))

# %%
train_set_second_version = train_set.copy()
val_set_second_version = val_set.copy()

train_set_second_version = add_alphabet_to_label(train_set_second_version)
val_set_second_version = add_alphabet_to_label(val_set_second_version)

train_set_second_version['Text'] = train_set_second_version['Text'].progress_apply(sentencepiece_tokenize)
val_set_second_version['Text'] = val_set_second_version['Text'].progress_apply(sentencepiece_tokenize)
# Out:
# 100%|██████████| 171089/171089 [00:14<00:00, 11739.47it/s]
# 100%|██████████| 19010/19010 [00:01<00:00, 12397.13it/s]
# 100%|██████████| 171089/171089 [00:08<00:00, 20222.44it/s]
# 100%|██████████| 19010/19010 [00:01<00:00, 16576.76it/s]

# %% [markdown]
# **4.3 Training**\
# \
# Same training as first approach

# %%
vectorizer_sp = TfidfVectorizer(analyzer="char", ngram_range=(1, 4), max_features=200000)
naive_bayes_sp = MultinomialNB(alpha= 0.001, fit_prior = False) 

pipeline = Pipeline([
    ('tfidf', vectorizer_sp),
    ('mnb', naive_bayes_sp)
])

x_train_sp = train_set_second_version['Text'].tolist()
y_train_sp = train_set_second_version['Label'].tolist()
x_val_sp = val_set_second_version['Text'].tolist()
y_val_sp = val_set_second_version['Label'].tolist()
y_total_sp = y_train_sp + y_val_sp

# converting categorical variables to numerical
from sklearn.preprocessing import LabelEncoder
le_sp = LabelEncoder()
le_sp.fit(y_total_sp)

y_train_sp = le_sp.transform(y_train_sp)
y_val_sp = le_sp.transform(y_val_sp)
label_mapping = dict(zip(le_sp.classes_, range(len(le_sp.classes_))))


pipeline.fit(x_train_sp, y_train_sp)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', max_features=200000,
#                                  ngram_range=(1, 4))),
#                 ('mnb', MultinomialNB(alpha=0.001, fit_prior=False))])

# %% [markdown]
# **4.4 Predictions**

# %%
predictions_sp = pipeline.predict(x_val_sp)
accuracy_sp = accuracy_score(y_val_sp, predictions_sp)
print("Raw accuracy:", accuracy_sp)

predicted_labels_sp = le_sp.inverse_transform(predictions_sp)
labels_to_predict = le_sp.inverse_transform(y_val_sp)

final_prediction = restore_labels(predicted_labels_sp)
val_to_predict = restore_labels(labels_to_predict)
final_accuracy = accuracy_score(val_to_predict, final_prediction)

print("Final accuracy:", final_accuracy)
# Out:
# Raw accuracy: 0.8531825355076276
# 100%|██████████| 19010/19010 [00:00<00:00, 1470884.72it/s]
# 100%|██████████| 19010/19010 [00:00<00:00, 1723487.86it/s]
# Final accuracy: 0.8548658600736454

# %% [markdown]
# **4.5 Results analysis**

# %%
# Generate the report with class indices
present_classes_sp = np.unique(np.concatenate((y_val_sp, predictions_sp)))
filtered_target_names_sp = [le_sp.classes_[i] for i in present_classes_sp]
report_sp = classification_report(y_val_sp, predictions_sp, target_names=filtered_target_names_sp, output_dict=True)

# Filter out non-class entries and sort ('accuracy', 'macro avg', 'weighted avg')
filtered_report = {label: metrics for label, metrics in report_sp.items() if isinstance(metrics, dict)}
sorted_report = sorted(filtered_report.items(), key=lambda x: x[1]['f1-score'], reverse=True)


print("Classification Report:\n")
for label, metrics in sorted_report:
    print(f"{label}: f1 = {metrics['f1-score']:.2f}, Pre = {metrics['precision']:.2f}, Rec = {metrics['recall']:.2f}, Support = {metrics['support']:0f}")
# Out:
# Classification Report:
#
# abk_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# ach_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 8.000000
# ahk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# alt_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# aoj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# arn_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# asm_Bengali: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# bem_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 38.000000
# bpy_Bengali: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# bqc_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# bzj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# cab_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# cak_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# ces_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# chk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# cjk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# csy_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# ctu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# cuk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# div_THAANA: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 39.000000
# djk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# fon_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# gom_Devanagari (Hindi, Sanskrit): f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 40.000000
# guc_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# guj_GUJARATI: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# gym_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# hbo_Hébreu: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# hnj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# hui_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# hus_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# iba_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# ikk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# iku_CANADIAN: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# ixl_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# kac_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# kal_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# kan_KANNADA: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# kbp_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# kek_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# khm_KHMER: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 35.000000
# khm_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# kjb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 40.000000
# kjh_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# kmb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 47.000000
# knv_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# kor_Hangul (Coréen): f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# kpg_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 56.000000
# ksd_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# ksw_MYANMAR: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# lhu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 20.000000
# lue_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 1.000000
# luo_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# lus_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# lvs_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# mah_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 2.000000
# mal_MALAYALAM: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# mam_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# mau_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# mco_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# meu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# mgh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 45.000000
# mon_Cyrillique: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# mps_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# mzh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 44.000000
# naq_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 59.000000
# nav_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# nch_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# ncj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 39.000000
# ngu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 49.000000
# nnb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# nyu_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 42.000000
# orm_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# ote_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# pan_GURMUKHI: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 52.000000
# poh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# pon_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 47.000000
# qub_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 2.000000
# qvi_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# rop_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 42.000000
# rug_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 50.000000
# seh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# srm_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# srn_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 46.000000
# suz_Devanagari (Hindi, Sanskrit): f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# tam_Tamoul: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# tbz_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 55.000000
# tca_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 43.000000
# tdt_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 38.000000
# tlh_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 41.000000
# toj_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 48.000000
# tok_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# top_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 51.000000
# tso_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# tuc_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 59.000000
# tuk_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# tzo_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# uig_Arabe: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 58.000000
# umb_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 52.000000
# vie_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 40.000000
# wal_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 63.000000
# xav_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 61.000000
# yao_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 57.000000
# yom_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 53.000000
# zai_Latin: f1 = 1.00, Pre = 1.00, Rec = 1.00, Support = 54.000000
# kir_Cyrillique: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 62.000000
# sgs_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 61.000000
# kbd_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 55.000000
# pap_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 55.000000
# roh_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 54.000000
# eus_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 54.000000
# quw_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 54.000000
# slk_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 54.000000
# sat_OL: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 52.000000
# mos_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 52.000000
# kos_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 51.000000
# yap_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 50.000000
# che_Cyrillique: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 50.000000
# sin_SINHALA: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 48.000000
# xmf_Géorgien: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 49.000000
# hun_Latin: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 47.000000
# ewe_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 47.000000
# lua_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 47.000000
# mya_MYANMAR: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 45.000000
# heb_Hébreu: f1 = 0.99, Pre = 0.98, Rec = 1.00, Support = 44.000000
# kik_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 42.000000
# mar_Devanagari (Hindi, Sanskrit): f1 = 0.99, Pre = 1.00, Rec = 0.98, Support = 41.000000
# yid_Hébreu: f1 = 0.99, Pre = 1.00, Rec = 0.97, Support = 39.000000
# tha_Thaï: f1 = 0.99, Pre = 0.97, Rec = 1.00, Support = 36.000000
# pls_Latin: f1 = 0.99, Pre = 1.00, Rec = 0.97, Support = 36.000000
# sag_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 63.000000
# mkd_Cyrillique: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 59.000000
# isl_Latin: f1 = 0.98, Pre = 0.97, Rec = 1.00, Support = 56.000000
# krc_Cyrillique: f1 = 0.98, Pre = 1.00, Rec = 0.97, Support = 58.000000
# sah_Cyrillique: f1 = 0.98, Pre = 1.00, Rec = 0.97, Support = 58.000000
# snd_Arabe: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 56.000000
# crh_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 55.000000
# jbo_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 54.000000
# fij_Latin: f1 = 0.98, Pre = 0.96, Rec = 1.00, Support = 50.000000
# fur_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 52.000000
# vol_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 52.000000
# fin_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 49.000000
# gom_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 49.000000
# ndo_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 48.000000
# cym_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 48.000000
# hmo_Latin: f1 = 0.98, Pre = 0.96, Rec = 1.00, Support = 46.000000
# diq_Latin: f1 = 0.98, Pre = 1.00, Rec = 0.96, Support = 47.000000
# csb_Latin: f1 = 0.98, Pre = 0.98, Rec = 0.98, Support = 44.000000
# eml_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 59.000000
# grc_Grec: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 59.000000
# lit_Latin: f1 = 0.97, Pre = 0.95, Rec = 1.00, Support = 55.000000
# oss_Cyrillique: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 58.000000
# azb_Arabe: f1 = 0.97, Pre = 0.98, Rec = 0.96, Support = 56.000000
# gug_Latin: f1 = 0.97, Pre = 0.96, Rec = 0.98, Support = 55.000000
# pms_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.95, Support = 38.000000
# pis_Latin: f1 = 0.97, Pre = 0.94, Rec = 1.00, Support = 17.000000
# szl_Latin: f1 = 0.97, Pre = 0.97, Rec = 0.97, Support = 34.000000
# vep_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 50.000000
# dtp_Latin: f1 = 0.97, Pre = 0.98, Rec = 0.96, Support = 47.000000
# glv_Latin: f1 = 0.97, Pre = 0.98, Rec = 0.96, Support = 47.000000
# kat_Géorgien: f1 = 0.97, Pre = 0.94, Rec = 1.00, Support = 45.000000
# sme_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 48.000000
# tpi_Latin: f1 = 0.97, Pre = 1.00, Rec = 0.94, Support = 48.000000
# kaz_Cyrillique: f1 = 0.97, Pre = 1.00, Rec = 0.93, Support = 46.000000
# mwl_Latin: f1 = 0.97, Pre = 0.97, Rec = 0.97, Support = 58.000000
# new_Devanagari (Hindi, Sanskrit): f1 = 0.96, Pre = 1.00, Rec = 0.93, Support = 59.000000
# bul_Cyrillique: f1 = 0.96, Pre = 0.98, Rec = 0.95, Support = 43.000000
# ell_Grec: f1 = 0.96, Pre = 0.93, Rec = 1.00, Support = 54.000000
# quh_Latin: f1 = 0.96, Pre = 0.93, Rec = 1.00, Support = 40.000000
# arz_Arabe: f1 = 0.96, Pre = 1.00, Rec = 0.93, Support = 55.000000
# kea_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 53.000000
# jam_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 64.000000
# frr_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 50.000000
# kam_Latin: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 38.000000
# kom_Cyrillique: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 50.000000
# tur_Latin: f1 = 0.96, Pre = 0.96, Rec = 0.96, Support = 48.000000
# amh_Éthiopien: f1 = 0.96, Pre = 1.00, Rec = 0.92, Support = 49.000000
# lin_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 48.000000
# ukr_Cyrillique: f1 = 0.96, Pre = 0.92, Rec = 1.00, Support = 45.000000
# lfn_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.94, Support = 47.000000
# kon_Latin: f1 = 0.96, Pre = 0.98, Rec = 0.93, Support = 58.000000
# swe_Latin: f1 = 0.95, Pre = 0.95, Rec = 0.96, Support = 54.000000
# epo_Latin: f1 = 0.95, Pre = 0.95, Rec = 0.95, Support = 43.000000
# tir_Éthiopien: f1 = 0.95, Pre = 0.91, Rec = 1.00, Support = 41.000000
# chv_Cyrillique: f1 = 0.95, Pre = 1.00, Rec = 0.91, Support = 44.000000
# ssw_Latin: f1 = 0.95, Pre = 0.98, Rec = 0.92, Support = 65.000000
# quc_Latin: f1 = 0.95, Pre = 0.94, Rec = 0.97, Support = 61.000000
# san_Devanagari (Hindi, Sanskrit): f1 = 0.95, Pre = 0.91, Rec = 1.00, Support = 59.000000
# fao_Latin: f1 = 0.95, Pre = 0.98, Rec = 0.92, Support = 53.000000
# hye_Arménien: f1 = 0.95, Pre = 0.91, Rec = 1.00, Support = 49.000000
# yor_Latin: f1 = 0.95, Pre = 1.00, Rec = 0.91, Support = 54.000000
# ace_Latin: f1 = 0.95, Pre = 0.98, Rec = 0.92, Support = 52.000000
# ilo_Latin: f1 = 0.95, Pre = 1.00, Rec = 0.91, Support = 53.000000
# cat_Latin: f1 = 0.95, Pre = 0.95, Rec = 0.95, Support = 40.000000
# grn_Latin: f1 = 0.95, Pre = 0.96, Rec = 0.94, Support = 50.000000
# lug_Latin: f1 = 0.95, Pre = 0.96, Rec = 0.94, Support = 50.000000
# gla_Latin: f1 = 0.95, Pre = 0.98, Rec = 0.92, Support = 50.000000
# bis_Latin: f1 = 0.95, Pre = 0.96, Rec = 0.93, Support = 58.000000
# ile_Latin: f1 = 0.94, Pre = 0.94, Rec = 0.94, Support = 53.000000
# aln_Latin: f1 = 0.94, Pre = 0.94, Rec = 0.94, Support = 52.000000
# acr_Latin: f1 = 0.94, Pre = 0.96, Rec = 0.92, Support = 52.000000
# tum_Latin: f1 = 0.94, Pre = 0.94, Rec = 0.94, Support = 51.000000
# ibo_Latin: f1 = 0.94, Pre = 1.00, Rec = 0.89, Support = 53.000000
# gcf_Latin: f1 = 0.94, Pre = 1.00, Rec = 0.88, Support = 17.000000
# slv_Latin: f1 = 0.94, Pre = 0.97, Rec = 0.90, Support = 41.000000
# afr_Latin: f1 = 0.94, Pre = 0.96, Rec = 0.91, Support = 56.000000
# kaa_Latin: f1 = 0.94, Pre = 1.00, Rec = 0.88, Support = 58.000000
# mhr_Cyrillique: f1 = 0.94, Pre = 0.94, Rec = 0.93, Support = 55.000000
# tyv_Cyrillique: f1 = 0.94, Pre = 0.95, Rec = 0.92, Support = 63.000000
# vls_Latin: f1 = 0.93, Pre = 0.93, Rec = 0.94, Support = 53.000000
# npi_Devanagari (Hindi, Sanskrit): f1 = 0.93, Pre = 0.94, Rec = 0.92, Support = 66.000000
# fry_Latin: f1 = 0.93, Pre = 0.96, Rec = 0.90, Support = 51.000000
# lao_LAO: f1 = 0.93, Pre = 0.89, Rec = 0.97, Support = 40.000000
# hsb_Latin: f1 = 0.93, Pre = 1.00, Rec = 0.87, Support = 52.000000
# quy_Latin: f1 = 0.93, Pre = 0.87, Rec = 1.00, Support = 45.000000
# bre_Latin: f1 = 0.92, Pre = 0.95, Rec = 0.90, Support = 60.000000
# dyu_Latin: f1 = 0.92, Pre = 0.87, Rec = 0.98, Support = 55.000000
# mzn_Arabe: f1 = 0.92, Pre = 0.98, Rec = 0.88, Support = 48.000000
# udm_Cyrillique: f1 = 0.92, Pre = 0.95, Rec = 0.89, Support = 46.000000
# gle_Latin: f1 = 0.92, Pre = 0.87, Rec = 0.98, Support = 53.000000
# pol_Latin: f1 = 0.92, Pre = 0.85, Rec = 1.00, Support = 46.000000
# ksh_Latin: f1 = 0.92, Pre = 0.95, Rec = 0.89, Support = 64.000000
# pus_Arabe: f1 = 0.92, Pre = 0.94, Rec = 0.89, Support = 57.000000
# kaa_Cyrillique: f1 = 0.92, Pre = 1.00, Rec = 0.85, Support = 59.000000
# bam_Latin: f1 = 0.91, Pre = 1.00, Rec = 0.84, Support = 51.000000
# rue_Cyrillique: f1 = 0.91, Pre = 0.86, Rec = 0.98, Support = 44.000000
# ven_Latin: f1 = 0.91, Pre = 1.00, Rec = 0.84, Support = 51.000000
# mai_Devanagari (Hindi, Sanskrit): f1 = 0.91, Pre = 0.93, Rec = 0.90, Support = 59.000000
# crh_Cyrillique: f1 = 0.91, Pre = 0.97, Rec = 0.86, Support = 42.000000
# hne_Devanagari (Hindi, Sanskrit): f1 = 0.91, Pre = 0.96, Rec = 0.86, Support = 59.000000
# tah_Latin: f1 = 0.91, Pre = 1.00, Rec = 0.83, Support = 48.000000
# ful_Latin: f1 = 0.91, Pre = 0.92, Rec = 0.90, Support = 49.000000
# zlm_Latin: f1 = 0.91, Pre = 0.91, Rec = 0.90, Support = 70.000000
# ron_Latin: f1 = 0.90, Pre = 0.87, Rec = 0.94, Support = 50.000000
# som_Latin: f1 = 0.90, Pre = 0.95, Rec = 0.85, Support = 48.000000
# jpn_Katakana (Japonais): f1 = 0.90, Pre = 0.90, Rec = 0.90, Support = 10.000000
# ext_Latin: f1 = 0.90, Pre = 0.92, Rec = 0.88, Support = 50.000000
# min_Latin: f1 = 0.90, Pre = 0.90, Rec = 0.90, Support = 48.000000
# ton_Latin: f1 = 0.90, Pre = 0.91, Rec = 0.88, Support = 49.000000
# pnb_Arabe: f1 = 0.89, Pre = 0.87, Rec = 0.92, Support = 50.000000
# tat_Cyrillique: f1 = 0.89, Pre = 0.82, Rec = 0.98, Support = 51.000000
# lij_Latin: f1 = 0.89, Pre = 0.86, Rec = 0.92, Support = 53.000000
# nap_Latin: f1 = 0.89, Pre = 0.92, Rec = 0.86, Support = 56.000000
# bih_Devanagari (Hindi, Sanskrit): f1 = 0.89, Pre = 0.84, Rec = 0.93, Support = 46.000000
# bod_TIBETAN: f1 = 0.88, Pre = 0.84, Rec = 0.93, Support = 45.000000
# hmn_Latin: f1 = 0.88, Pre = 0.98, Rec = 0.80, Support = 51.000000
# pcd_Latin: f1 = 0.88, Pre = 0.83, Rec = 0.95, Support = 55.000000
# nld_Latin: f1 = 0.88, Pre = 0.85, Rec = 0.92, Support = 48.000000
# por_Latin: f1 = 0.88, Pre = 0.91, Rec = 0.85, Support = 47.000000
# ceb_Latin: f1 = 0.88, Pre = 0.92, Rec = 0.84, Support = 43.000000
# ido_Latin: f1 = 0.88, Pre = 0.86, Rec = 0.90, Support = 40.000000
# dan_Latin: f1 = 0.87, Pre = 0.90, Rec = 0.84, Support = 45.000000
# wol_Latin: f1 = 0.87, Pre = 0.94, Rec = 0.81, Support = 42.000000
# lzh_Kanji (Chinois, Japonais, Coréen): f1 = 0.87, Pre = 0.82, Rec = 0.93, Support = 58.000000
# swc_Latin: f1 = 0.87, Pre = 0.92, Rec = 0.82, Support = 57.000000
# arg_Latin: f1 = 0.87, Pre = 0.84, Rec = 0.90, Support = 59.000000
# pag_Latin: f1 = 0.87, Pre = 0.98, Rec = 0.78, Support = 55.000000
# deu_Latin: f1 = 0.87, Pre = 0.84, Rec = 0.89, Support = 47.000000
# myv_Cyrillique: f1 = 0.87, Pre = 0.82, Rec = 0.92, Support = 63.000000
# mon_Latin: f1 = 0.86, Pre = 0.95, Rec = 0.80, Support = 44.000000
# pcm_Latin: f1 = 0.86, Pre = 0.85, Rec = 0.87, Support = 67.000000
# lmo_Latin: f1 = 0.86, Pre = 0.84, Rec = 0.88, Support = 41.000000
# rmy_Latin: f1 = 0.86, Pre = 0.95, Rec = 0.78, Support = 54.000000
# weighted avg: f1 = 0.85, Pre = 0.87, Rec = 0.85, Support = 19010.000000
# dzo_TIBETAN: f1 = 0.85, Pre = 0.86, Rec = 0.85, Support = 52.000000
# lim_Latin: f1 = 0.85, Pre = 0.84, Rec = 0.87, Support = 47.000000
# tls_Latin: f1 = 0.85, Pre = 0.97, Rec = 0.75, Support = 52.000000
# lat_Latin: f1 = 0.85, Pre = 0.80, Rec = 0.90, Support = 49.000000
# gsw_Latin: f1 = 0.85, Pre = 0.83, Rec = 0.86, Support = 35.000000
# yue_Kanji (Chinois, Japonais, Coréen): f1 = 0.84, Pre = 0.85, Rec = 0.84, Support = 68.000000
# pfl_Latin: f1 = 0.84, Pre = 0.83, Rec = 0.85, Support = 41.000000
# ayr_Latin: f1 = 0.84, Pre = 0.75, Rec = 0.96, Support = 45.000000
# nno_Latin: f1 = 0.84, Pre = 0.76, Rec = 0.95, Support = 39.000000
# rap_Latin: f1 = 0.84, Pre = 0.95, Rec = 0.75, Support = 24.000000
# hif_Latin: f1 = 0.84, Pre = 0.79, Rec = 0.88, Support = 43.000000
# uzb_Latin: f1 = 0.83, Pre = 0.78, Rec = 0.90, Support = 58.000000
# macro avg: f1 = 0.83, Pre = 0.85, Rec = 0.83, Support = 19010.000000
# glg_Latin: f1 = 0.82, Pre = 0.83, Rec = 0.82, Support = 49.000000
# kat_Latin: f1 = 0.82, Pre = 0.91, Rec = 0.75, Support = 56.000000
# zea_Latin: f1 = 0.82, Pre = 0.87, Rec = 0.77, Support = 44.000000
# nep_Devanagari (Hindi, Sanskrit): f1 = 0.82, Pre = 0.80, Rec = 0.84, Support = 43.000000
# mlt_Latin: f1 = 0.82, Pre = 0.81, Rec = 0.83, Support = 46.000000
# nds_Latin: f1 = 0.82, Pre = 0.78, Rec = 0.86, Support = 44.000000
# bak_Cyrillique: f1 = 0.82, Pre = 0.98, Rec = 0.70, Support = 57.000000
# hrx_Latin: f1 = 0.81, Pre = 1.00, Rec = 0.69, Support = 16.000000
# bar_Latin: f1 = 0.81, Pre = 0.74, Rec = 0.91, Support = 55.000000
# fra_Latin: f1 = 0.81, Pre = 0.78, Rec = 0.85, Support = 46.000000
# scn_Latin: f1 = 0.81, Pre = 0.84, Rec = 0.78, Support = 63.000000
# kur_Latin: f1 = 0.81, Pre = 0.74, Rec = 0.89, Support = 57.000000
# hau_Latin: f1 = 0.81, Pre = 0.78, Rec = 0.84, Support = 50.000000
# oci_Latin: f1 = 0.80, Pre = 0.87, Rec = 0.74, Support = 46.000000
# smo_Latin: f1 = 0.80, Pre = 0.97, Rec = 0.68, Support = 50.000000
# kmr_Latin: f1 = 0.80, Pre = 0.95, Rec = 0.69, Support = 54.000000
# hat_Latin: f1 = 0.79, Pre = 0.90, Rec = 0.71, Support = 51.000000
# nso_Latin: f1 = 0.78, Pre = 0.78, Rec = 0.78, Support = 45.000000
# plt_Latin: f1 = 0.78, Pre = 0.98, Rec = 0.65, Support = 65.000000
# jpn_Hiragana (Japonais): f1 = 0.77, Pre = 0.68, Rec = 0.89, Support = 19.000000
# uig_Latin: f1 = 0.77, Pre = 0.85, Rec = 0.70, Support = 47.000000
# haw_Latin: f1 = 0.77, Pre = 0.89, Rec = 0.67, Support = 46.000000
# aka_Latin: f1 = 0.76, Pre = 0.77, Rec = 0.76, Support = 49.000000
# bsb_Latin: f1 = 0.75, Pre = 0.80, Rec = 0.71, Support = 49.000000
# ber_Latin: f1 = 0.75, Pre = 0.83, Rec = 0.68, Support = 57.000000
# ina_Latin: f1 = 0.75, Pre = 0.79, Rec = 0.71, Support = 48.000000
# que_Latin: f1 = 0.74, Pre = 0.94, Rec = 0.61, Support = 49.000000
# prs_Arabe: f1 = 0.74, Pre = 0.63, Rec = 0.89, Support = 54.000000
# bjn_Latin: f1 = 0.74, Pre = 0.74, Rec = 0.73, Support = 48.000000
# kab_Latin: f1 = 0.73, Pre = 0.65, Rec = 0.83, Support = 47.000000
# hil_Latin: f1 = 0.73, Pre = 1.00, Rec = 0.57, Support = 7.000000
# srd_Latin: f1 = 0.72, Pre = 0.92, Rec = 0.60, Support = 57.000000
# hbs_Cyrillique: f1 = 0.72, Pre = 0.65, Rec = 0.81, Support = 53.000000
# gor_Latin: f1 = 0.72, Pre = 0.92, Rec = 0.59, Support = 37.000000
# twi_Latin: f1 = 0.72, Pre = 0.73, Rec = 0.71, Support = 52.000000
# wuu_Kanji (Chinois, Japonais, Coréen): f1 = 0.72, Pre = 0.66, Rec = 0.79, Support = 47.000000
# run_Latin: f1 = 0.72, Pre = 0.62, Rec = 0.86, Support = 49.000000
# tsn_Latin: f1 = 0.72, Pre = 0.72, Rec = 0.72, Support = 46.000000
# ast_Latin: f1 = 0.72, Pre = 0.61, Rec = 0.88, Support = 49.000000
# mlg_Latin: f1 = 0.71, Pre = 0.62, Rec = 0.83, Support = 54.000000
# bak_Latin: f1 = 0.71, Pre = 0.69, Rec = 0.73, Support = 49.000000
# bew_Cyrillique: f1 = 0.71, Pre = 0.72, Rec = 0.71, Support = 51.000000
# est_Latin: f1 = 0.71, Pre = 0.75, Rec = 0.68, Support = 56.000000
# cbk_Latin: f1 = 0.71, Pre = 0.83, Rec = 0.61, Support = 49.000000
# arb_Arabe: f1 = 0.70, Pre = 0.63, Rec = 0.80, Support = 54.000000
# bel_Cyrillique: f1 = 0.70, Pre = 0.71, Rec = 0.69, Support = 52.000000
# hin_Devanagari (Hindi, Sanskrit): f1 = 0.70, Pre = 0.68, Rec = 0.72, Support = 50.000000
# jav_Latin: f1 = 0.69, Pre = 0.70, Rec = 0.69, Support = 48.000000
# aym_Latin: f1 = 0.69, Pre = 0.90, Rec = 0.56, Support = 50.000000
# ekk_Latin: f1 = 0.69, Pre = 0.65, Rec = 0.74, Support = 42.000000
# nya_Latin: f1 = 0.68, Pre = 0.77, Rec = 0.61, Support = 49.000000
# cmn_Kanji (Chinois, Japonais, Coréen): f1 = 0.68, Pre = 0.64, Rec = 0.71, Support = 35.000000
# spa_Latin: f1 = 0.67, Pre = 0.64, Rec = 0.71, Support = 48.000000
# mri_Latin: f1 = 0.67, Pre = 0.79, Rec = 0.57, Support = 47.000000
# mya_Latin: f1 = 0.67, Pre = 1.00, Rec = 0.50, Support = 2.000000
# nbl_Latin: f1 = 0.67, Pre = 0.54, Rec = 0.86, Support = 36.000000
# ori_ORIYA: f1 = 0.66, Pre = 0.66, Rec = 0.66, Support = 41.000000
# wln_Latin: f1 = 0.65, Pre = 0.69, Rec = 0.62, Support = 50.000000
# aze_Arabe: f1 = 0.65, Pre = 0.65, Rec = 0.65, Support = 63.000000
# srp_Latin: f1 = 0.65, Pre = 0.66, Rec = 0.64, Support = 55.000000
# ita_Latin: f1 = 0.65, Pre = 0.57, Rec = 0.74, Support = 43.000000
# sqi_Latin: f1 = 0.65, Pre = 0.55, Rec = 0.78, Support = 40.000000
# ckb_Arabe: f1 = 0.64, Pre = 0.53, Rec = 0.83, Support = 46.000000
# jpn_Kanji (Chinois, Japonais, Coréen): f1 = 0.64, Pre = 0.82, Rec = 0.53, Support = 17.000000
# war_Latin: f1 = 0.64, Pre = 0.64, Rec = 0.64, Support = 42.000000
# xho_Latin: f1 = 0.64, Pre = 0.87, Rec = 0.51, Support = 51.000000
# aze_Latin: f1 = 0.64, Pre = 0.61, Rec = 0.67, Support = 49.000000
# ory_ORIYA: f1 = 0.63, Pre = 0.63, Rec = 0.63, Support = 38.000000
# azj_Latin: f1 = 0.62, Pre = 0.64, Rec = 0.59, Support = 49.000000
# hbs_Latin: f1 = 0.62, Pre = 0.49, Rec = 0.82, Support = 49.000000
# zho_Kanji (Chinois, Japonais, Coréen): f1 = 0.62, Pre = 0.76, Rec = 0.52, Support = 62.000000
# nob_Latin: f1 = 0.61, Pre = 0.60, Rec = 0.63, Support = 49.000000
# swa_Latin: f1 = 0.61, Pre = 0.60, Rec = 0.62, Support = 48.000000
# ban_Latin: f1 = 0.60, Pre = 0.67, Rec = 0.54, Support = 57.000000
# tgl_Latin: f1 = 0.59, Pre = 0.66, Rec = 0.54, Support = 61.000000
# urd_Arabe: f1 = 0.59, Pre = 0.48, Rec = 0.78, Support = 50.000000
# mad_Latin: f1 = 0.59, Pre = 0.62, Rec = 0.56, Support = 55.000000
# glk_Arabe: f1 = 0.59, Pre = 0.62, Rec = 0.56, Support = 45.000000
# guj_Devanagari (Hindi, Sanskrit): f1 = 0.56, Pre = 0.53, Rec = 0.60, Support = 52.000000
# srp_Cyrillique: f1 = 0.56, Pre = 0.65, Rec = 0.49, Support = 45.000000
# sot_Latin: f1 = 0.55, Pre = 0.60, Rec = 0.50, Support = 60.000000
# tat_Latin: f1 = 0.54, Pre = 0.75, Rec = 0.42, Support = 50.000000
# swh_Latin: f1 = 0.54, Pre = 0.53, Rec = 0.54, Support = 46.000000
# kur_Arabe: f1 = 0.53, Pre = 0.75, Rec = 0.41, Support = 58.000000
# hau_Arabe: f1 = 0.53, Pre = 0.66, Rec = 0.44, Support = 66.000000
# ltz_Latin: f1 = 0.52, Pre = 0.38, Rec = 0.84, Support = 43.000000
# sun_Latin: f1 = 0.52, Pre = 0.44, Rec = 0.63, Support = 43.000000
# cos_Latin: f1 = 0.52, Pre = 0.48, Rec = 0.57, Support = 53.000000
# kin_Latin: f1 = 0.51, Pre = 0.51, Rec = 0.50, Support = 40.000000
# tgk_Latin: f1 = 0.51, Pre = 0.64, Rec = 0.42, Support = 50.000000
# bik_Latin: f1 = 0.51, Pre = 0.46, Rec = 0.56, Support = 43.000000
# enm_Latin: f1 = 0.50, Pre = 1.00, Rec = 0.33, Support = 3.000000
# nor_Latin: f1 = 0.50, Pre = 0.55, Rec = 0.46, Support = 46.000000
# tuk_Cyrillique: f1 = 0.50, Pre = 0.35, Rec = 0.88, Support = 17.000000
# ary_Arabe: f1 = 0.50, Pre = 0.49, Rec = 0.50, Support = 54.000000
# tgk_Cyrillique: f1 = 0.49, Pre = 0.63, Rec = 0.40, Support = 47.000000
# uzn_Cyrillique: f1 = 0.49, Pre = 0.51, Rec = 0.47, Support = 53.000000
# ara_Arabe: f1 = 0.48, Pre = 0.37, Rec = 0.70, Support = 54.000000
# sna_Latin: f1 = 0.48, Pre = 0.74, Rec = 0.35, Support = 48.000000
# apc_Arabe: f1 = 0.47, Pre = 0.45, Rec = 0.50, Support = 52.000000
# nde_Latin: f1 = 0.47, Pre = 0.48, Rec = 0.47, Support = 43.000000
# pam_Latin: f1 = 0.47, Pre = 0.42, Rec = 0.52, Support = 46.000000
# vec_Latin: f1 = 0.46, Pre = 0.44, Rec = 0.49, Support = 39.000000
# san_Latin: f1 = 0.46, Pre = 0.43, Rec = 0.50, Support = 6.000000
# msa_Latin: f1 = 0.46, Pre = 0.41, Rec = 0.52, Support = 52.000000
# pes_Arabe: f1 = 0.45, Pre = 0.45, Rec = 0.45, Support = 44.000000
# acm_Arabe: f1 = 0.45, Pre = 0.63, Rec = 0.35, Support = 55.000000
# hin_Latin: f1 = 0.44, Pre = 0.48, Rec = 0.42, Support = 48.000000
# als_Latin: f1 = 0.43, Pre = 0.56, Rec = 0.35, Support = 40.000000
# eng_Latin: f1 = 0.42, Pre = 0.30, Rec = 0.74, Support = 54.000000
# ind_Latin: f1 = 0.41, Pre = 0.38, Rec = 0.44, Support = 36.000000
# sco_Latin: f1 = 0.41, Pre = 0.28, Rec = 0.75, Support = 68.000000
# ajp_Arabe: f1 = 0.41, Pre = 0.33, Rec = 0.54, Support = 35.000000
# fil_Latin: f1 = 0.40, Pre = 0.38, Rec = 0.41, Support = 39.000000
# bcl_Latin: f1 = 0.39, Pre = 0.34, Rec = 0.47, Support = 57.000000
# fas_Arabe: f1 = 0.39, Pre = 0.41, Rec = 0.36, Support = 44.000000
# uzb_Cyrillique: f1 = 0.38, Pre = 0.32, Rec = 0.49, Support = 47.000000
# zul_Latin: f1 = 0.36, Pre = 0.47, Rec = 0.30, Support = 47.000000
# zsm_Latin: f1 = 0.36, Pre = 0.33, Rec = 0.40, Support = 40.000000
# afb_Arabe: f1 = 0.31, Pre = 0.37, Rec = 0.27, Support = 48.000000
# som_Arabe: f1 = 0.28, Pre = 0.82, Rec = 0.17, Support = 53.000000
# tgk_Arabe: f1 = 0.26, Pre = 0.41, Rec = 0.19, Support = 47.000000
# lao_Latin: f1 = 0.25, Pre = 0.50, Rec = 0.17, Support = 6.000000
# bos_Latin: f1 = 0.24, Pre = 0.31, Rec = 0.20, Support = 50.000000
# guj_Latin: f1 = 0.22, Pre = 0.33, Rec = 0.17, Support = 6.000000
# hrv_Latin: f1 = 0.17, Pre = 0.22, Rec = 0.14, Support = 36.000000
# dzo_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 4.000000
# hyw_Arménien: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 4.000000
# mai_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# ngl_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# quz_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# sat_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# sin_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# tha_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# wbm_Latin: f1 = 0.00, Pre = 0.00, Rec = 0.00, Support = 1.000000
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/hippolytelecomte/Documents/Etudes/CentraleSupelec/3A/ANLP/TD/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
val_set_second_version[val_set_second_version['Label'] == 'bos_Latin'].head()
# Out:
#          Usage                                               Text      Label
# 34789   Public  ▁ B. ▁ 2 4SI ▁ - ▁ I stra ži vanje ▁od s je ka...  bos_Latin
# 187584  Public  ▁ I ▁svak og ▁dana ▁na kon ▁to ga ▁je ▁laga no...  bos_Latin
# 172443  Public  ▁ S lu ša j ! ▁ G de ▁je ▁čo ve k ▁koji ▁je ▁p...  bos_Latin
# 1390    Public  ▁ E ki pa ▁ J a pan ske ▁se ▁sa sto ja la ▁od ...  bos_Latin
# 49647   Public  ▁ Ž ene ▁će ▁pu ca ti ▁ako ▁su ▁iz gu bile ▁si...  bos_Latin

# %% [markdown]
# ### **5. GridSearch to choose the best model**

# %% [markdown]
# - The use of GridSearch is highly resource-intensive.
# - Therefore, we reduce the dimensionality of the vectors (max_features in TF-IDF) to 2000 and select only models with reasonable complexity for 𝑛≈190,000 and 𝑑≈2000
# - This provides a proxy for the best model-hyperparameter combination among these lightweight options.
# - We do not consider adding the alphabet here, as it creates issues with excessively small classes in cross-validation.

# %%
from sklearn.linear_model import SGDClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Removing extremely underrepresented languages (<10 instances)

# %%
dataset_sorted_by_number_instances_by_language = data_train_without_nan_for_label.groupby("Label").count().sort_values('Usage', ascending=True)
dataset_sorted_by_number_instances_by_language.head()
df = dataset_sorted_by_number_instances_by_language
underrepresented_languages = list(df[df['Text']<10].index)
data_train_without_nan_for_label = data_train_without_nan_for_label[~data_train_without_nan_for_label.isin(underrepresented_languages)]

# %%
train_set, val_set = train_test_split(data_train_without_nan_for_label, test_size=0.1, random_state=42)

train_set_third_version = train_set.copy()
val_set_third_version = val_set.copy()

train_set_third_version = pre_processing(train_set_third_version, remove_espace=False, not_test=False) 
val_set_third_version = pre_processing(val_set_third_version, remove_espace=False, not_test=False)

# %%
x_train = train_set_third_version['Text'].tolist()
y_train = train_set_third_version['Label'].tolist()
x_val = val_set_third_version['Text'].tolist()
y_val = val_set_third_version['Label'].tolist()
y_total = y_train + y_val

le = LabelEncoder()
le.fit(y_total)

y_train = le.transform(y_train)
y_val = le.transform(y_val)
label_mapping = dict(zip(le.classes_, range(len(le.classes_))))

# %%
param_grid = [
    {
        'classifier': [MultinomialNB()],
        'classifier__alpha': [0.001, 0.01, 0.1, 1.0],
        'classifier__fit_prior': [True, False]
    },
    {
        'classifier': [SGDClassifier(max_iter=1000, tol=1e-3)],
        'classifier__loss': ['log_loss'],  # Régression logistique
        'classifier__alpha': [1e-4, 1e-3, 1e-2],
        'classifier__penalty': ['l2']
    }
] 

pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(analyzer="char", ngram_range=(1, 5), max_features=2000)), # Max_features to 2000 to reduce computing time
    ('classifier', MultinomialNB()) 
])

grid_search = GridSearchCV(pipeline, param_grid, cv=2, scoring='accuracy', verbose=2, n_jobs=-1)
grid_search.fit(x_train, y_train)

best_model = grid_search.best_estimator_
print(f"Best model : {best_model}")

predictions = best_model.predict(x_val)
accuracy = accuracy_score(y_val, predictions)

print("Best hyperparameters:", grid_search.best_params_)
print("Accuracy on validation set:", accuracy)
# Out:
# Fitting 2 folds for each of 11 candidates, totalling 22 fits
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.01, classifier__fit_prior=True; total time= 3.7min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.001, classifier__fit_prior=False; total time= 3.7min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.01, classifier__fit_prior=False; total time= 3.8min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.001, classifier__fit_prior=False; total time= 3.8min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.01, classifier__fit_prior=False; total time= 3.8min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.001, classifier__fit_prior=True; total time= 3.8min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.01, classifier__fit_prior=True; total time= 3.8min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.001, classifier__fit_prior=True; total time= 3.8min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.1, classifier__fit_prior=True; total time= 2.3min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.1, classifier__fit_prior=True; total time= 2.3min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.1, classifier__fit_prior=False; total time= 2.4min
# [CV] END classifier=MultinomialNB(), classifier__alpha=0.1, classifier__fit_prior=False; total time= 2.4min
# [CV] END classifier=MultinomialNB(), classifier__alpha=1.0, classifier__fit_prior=True; total time= 2.4min
# [CV] END classifier=MultinomialNB(), classifier__alpha=1.0, classifier__fit_prior=False; total time= 2.4min
# [CV] END classifier=MultinomialNB(), classifier__alpha=1.0, classifier__fit_prior=True; total time= 2.4min
# [CV] END classifier=MultinomialNB(), classifier__alpha=1.0, classifier__fit_prior=False; total time= 2.4min
# [CV] END classifier=SGDClassifier(), classifier__alpha=0.0001, classifier__loss=log_loss, classifier__penalty=l2; total time= 4.2min
# [CV] END classifier=SGDClassifier(), classifier__alpha=0.0001, classifier__loss=log_loss, classifier__penalty=l2; total time= 4.2min
# [CV] END classifier=SGDClassifier(), classifier__alpha=0.001, classifier__loss=log_loss, classifier__penalty=l2; total time= 4.2min
# [CV] END classifier=SGDClassifier(), classifier__alpha=0.001, classifier__loss=log_loss, classifier__penalty=l2; total time= 4.2min
# [CV] END classifier=SGDClassifier(), classifier__alpha=0.01, classifier__loss=log_loss, classifier__penalty=l2; total time= 4.9min
# [CV] END classifier=SGDClassifier(), classifier__alpha=0.01, classifier__loss=log_loss, classifier__penalty=l2; total time= 4.9min
# Meilleur modèle : Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', max_features=2000,
#                                  ngram_range=(1, 5))),
#                 ('classifier', MultinomialNB(alpha=0.01))])
# Meilleurs hyperparamètres : {'classifier': MultinomialNB(), 'classifier__alpha': 0.01, 'classifier__fit_prior': True}
# Accuracy sur le set de validation: 0.751709626512362

# %%
pd.set_option('display.max_colwidth', None) 

results_df = pd.DataFrame(grid_search.cv_results_)
accuracy_results = results_df[['params', 'mean_test_score', 'std_test_score']]
accuracy_results = accuracy_results.sort_values(by='mean_test_score', ascending=False)
accuracy_results.head()

accuracy_results.to_csv("grid_search_results.csv", index=False)
# Out:
#                                                                                                                        params  \
# 2                                   {'classifier': MultinomialNB(), 'classifier__alpha': 0.01, 'classifier__fit_prior': True}
# 4                                    {'classifier': MultinomialNB(), 'classifier__alpha': 0.1, 'classifier__fit_prior': True}
# 0                                  {'classifier': MultinomialNB(), 'classifier__alpha': 0.001, 'classifier__fit_prior': True}
# 3                                  {'classifier': MultinomialNB(), 'classifier__alpha': 0.01, 'classifier__fit_prior': False}
# 5                                   {'classifier': MultinomialNB(), 'classifier__alpha': 0.1, 'classifier__fit_prior': False}
# 1                                 {'classifier': MultinomialNB(), 'classifier__alpha': 0.001, 'classifier__fit_prior': False}
# 6                                    {'classifier': MultinomialNB(), 'classifier__alpha': 1.0, 'classifier__fit_prior': True}
# 7                                   {'classifier': MultinomialNB(), 'classifier__alpha': 1.0, 'classifier__fit_prior': False}
# 8   {'classifier': SGDClassifier(), 'classifier__alpha': 0.0001, 'classifier__loss': 'log_loss', 'classifier__penalty': 'l2'}
# 9    {'classifier': SGDClassifier(), 'classifier__alpha': 0.001, 'classifier__loss': 'log_loss', 'classifier__penalty': 'l2'}
# 10    {'classifier': SGDClassifier(), 'classifier__alpha': 0.01, 'classifier__loss': 'log_loss', 'classifier__penalty': 'l2'}
#
#     mean_test_score  std_test_score
# 2          0.744373        0.002260
# 4          0.742877        0.002506
# 0          0.742239        0.001927
# 3          0.742140        0.002646
# 5          0.740346        0.002360
# 1          0.739299        0.001805
# 6          0.732058        0.002114
# 7          0.726651        0.002599
# 8          0.717007        0.001875
# 9          0.644156        0.005147
# 10         0.563233        0.002826

# %%
accuracy_results.to_csv("grid_search_results.csv", index=False)

# %% [markdown]
# ### **6. Submission**

# %%
train = data_train_without_nan_for_label.copy()
train = pre_processing(train, remove_espace=False)

x = train['Text'].tolist()
y = train['Label'].tolist()

vectorizer= TfidfVectorizer(analyzer="char", ngram_range=(1, 5), max_features=200000)
best_model = grid_search.best_estimator_['classifier']

best_pipeline = Pipeline([
    ('tfidf', vectorizer),
    ('classifier', best_model)
])

le_test = LabelEncoder()
y = le_test.fit_transform(y)
label_mapping_test = dict(zip(le_test.classes_, range(len(le_test.classes_))))

best_pipeline.fit(x, y)
# Out:
# 100%|██████████| 190099/190099 [00:07<00:00, 26369.50it/s]
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', max_features=200000,
#                                  ngram_range=(1, 5))),
#                 ('classifier', MultinomialNB(alpha=0.001))])

# %%
data_test= pd.read_csv(file_path_test)
test_set = pre_processing(data_test, remove_espace=False, not_test=False)
x_test = test_set['Text'].tolist()

predictions_test = best_pipeline.predict(x_test)
predicted_labels_test = le_test.inverse_transform(predictions_test)
predicted_labels_test = restore_labels(predicted_labels_test)
test_set['Label'] = predicted_labels_test

column_ID = [i for i in range(1, len(test_set)+1)]
test_set['ID'] = column_ID

test_set[['ID', 'Label']].to_csv('test_set_v9_sans_tokenizer_predicted.csv', index=False)
# Out:
# 100%|██████████| 190567/190567 [00:00<00:00, 2933874.36it/s]

# %% [markdown]
# ## Annexe: Submition d'un modèle ad-hoc

# %% [markdown]
# Entraînement du modèle choisi sur tout le train set

# %%
from sklearn.pipeline import Pipeline

train = data_train_without_nan_for_label.copy()
train = pre_processing(train, remove_espace=False, not_test=False)
train = add_alphabet_to_label(train)
# train['Text'] = train['Text'].progress_apply(sentencepiece_tokenize)
x = train['Text'].tolist()
y = train['Label'].tolist()

vectorizer= TfidfVectorizer(analyzer="char", ngram_range=(1, 5), max_features=200000)
sgd_classifier = SGDClassifier(alpha=0.0001, loss='log_loss', penalty='l2')

best_pipeline = Pipeline([
    ('tfidf', vectorizer),
    ('mnb', sgd_classifier)
])

from sklearn.preprocessing import LabelEncoder
le_test = LabelEncoder()
y = le_test.fit_transform(y)
label_mapping_test = dict(zip(le_test.classes_, range(len(le_test.classes_))))

best_pipeline.fit(x, y)
# Out:
# 100%|██████████| 190099/190099 [00:07<00:00, 25886.97it/s]
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', max_features=200000,
#                                  ngram_range=(1, 5))),
#                 ('mnb', SGDClassifier(loss='log_loss'))])

# %% [markdown]
# Prédiction des labels pour le test et génération du csv à déposer

# %%
data_test= pd.read_csv(file_path_test)
test_set = pre_processing(data_test, remove_espace=False, not_test=False)
# test_set['Text'] = test_set['Text'].progress_apply(sentencepiece_tokenize)

x_test = test_set['Text'].tolist()
predictions_test = best_pipeline.predict(x_test)

# %%
test_set.to_csv('test_preprocessed.csv', index=False)

# %%
predicted_labels_test = le_test.inverse_transform(predictions_test)
predicted_labels_test = restore_labels(predicted_labels_test)
test_set['Label'] = predicted_labels_test
# Out:
# 100%|██████████| 190567/190567 [00:00<00:00, 1810442.61it/s]

# %%
column_ID = [i for i in range(1, len(test_set)+1)]
test_set['ID'] = column_ID

# %%
test_set[['ID', 'Label']].to_csv('test_set_v10_sans_tokenizer_predicted.csv', index=False)
